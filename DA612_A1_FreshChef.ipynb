# %% [markdown]
# <a href="https://colab.research.google.com/github/hxiufan/GA612_Activities/blob/main/DA612_A1_FreshChef.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://freshchef.nz/collections/frontpage"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
table = soup.find('div', class_='product-grid-container scroll-trigger animate--slide-in')

# %%
meals = table.find_all('li', class_='grid__item scroll-trigger animate--slide-in')

# %%
meals_all = []

# %%
for meal in meals:
   title = meal.find('h3').text.replace('\n', '')
   urls = meal.find('a').get('href')
   price = meal.find('span',class_='price-item price-item--regular').text.strip()
   price = float(price[1:])

   meals_all.append([title,price,urls])

# %%
print (meals_all)
# Out:
# [['                Slow Roasted Pork & Vegetables  ✓              ', 17.9, '/products/slow-roasted-pork-vegetables-meal-gf-frozen-meal'], ['                Chicken Breast, Mash, Bacon & Mushroom ✓              ', 17.9, '/products/chicken-breast-with-bacon-mushroom-sauce-gf'], ['                Slow Roasted Beef & Vegetables  ✓              ', 17.9, '/products/copy-of-authentic-butter-chicken-basmati-rice-frozen-prepared-meal-gluten-free'], ['                Lasagne with Beef Mince & Cheese              ', 17.9, '/products/lasagne-frozen-meal'], ['                Sticky Beef Cheek & Kumara  ✓              ', 18.4, '/products/sticky-beef-cheek-and-kumara'], ['                Moroccan Lamb with Kumara Mash  ✓              ', 18.9, '/products/pulled-lamb-shoulder-gf'], ['                Roast Chicken Breast & Vegetables  ✓              ', 17.9, '/products/roast-chicken-breast-vegetables'], ['                Sweet and Sour Pork   ✓              ', 16.9, '/products/sweet-and-sour-pork'], [
# ...

# %%
data = pd.DataFrame(meals_all, columns=['Meal', 'Price', 'URL'])

# %%
data
# Out:
#                                                  Meal  Price  \
# 0                   Slow Roasted Pork & Vegetables...  17.90
# 1                   Chicken Breast, Mash, Bacon & ...  17.90
# 2                   Slow Roasted Beef & Vegetables...  17.90
# 3                   Lasagne with Beef Mince & Chee...  17.90
# 4                   Sticky Beef Cheek & Kumara  ✓ ...  18.40
# 5                   Moroccan Lamb with Kumara Mash...  18.90
# 6                   Roast Chicken Breast & Vegetab...  17.90
# 7                   Sweet and Sour Pork   ✓       ...  16.90
# 8                   Glazed Christmas Ham & Veg  ✓ ...  17.90
# 9                   Mac n Cheese with  Ham        ...  15.90
# 10                  Fish & White Sauce with Kumara...  17.90
# 11                  Truffle Mac n Cheese n Ham    ...  16.90
# 12                  Creamy Seafood Chowder        ...  18.40
# 13                  Chef Steve's Pork Schnitzel & ...  15.99
# ...

# %%
data.to_csv("/content/drive/My Drive/DA612/FreshChef_meals.csv")
