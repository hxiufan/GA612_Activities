# %% [markdown]
# <a href="https://colab.research.google.com/github/hxiufan/GA612_Activities/blob/main/DA612_A1_RipeDeli_cleansing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os

# %%
os.chdir('/content/drive/My Drive/DA612')

# %%
# Read the dataset
df = pd.read_csv('RipeDeli_meals.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  14 non-null     int64
#  1   Meal        14 non-null     object
#  2   Price       14 non-null     object
#  3   URL         14 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 576.0+ bytes

# %%
df.head(10)
# Out:
#    Unnamed: 0                                 Meal        Price  \
# 0           0          Fill The Freezer Care Packs  from$160.00
# 1           1          Fill The Freezer With Soups  from$116.00
# 2           2  Vegan Turmeric Coconut Curry + Tofu   from$34.00
# 3           3     Vegan Mushroom & Quinoa Moussaka   from$34.00
# 4           4     Courgette Spinach & Feta Lasagna   from$34.00
# 5           5                           Beef Daube   from$36.00
# 6           6                       Butter Chicken   from$36.00
# 7           7                   Chicken & Leek Pie   from$36.00
# 8           8                       Lamb Meatballs   from$34.00
# 9           9                        Shepherds Pie   from$34.00
#
#                                                  URL
# 0  /collections/instore-pickup-freezer-meals-bbq-...
# 1  /collections/instore-pickup-freezer-meals-bbq-...
# 2  /collections/instore-pickup-freezer-meals-bbq-...
# ...

# %%
# Identify and handle missing values
missing_data = df.isnull().sum()

print("Missing data per column:")
print(missing_data)
# Out:
# Missing data per column:
# Unnamed: 0    0
# Meal          0
# Price         0
# URL           0
# dtype: int64

# %%
# Identify if there are duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check spelling with textblob, but not ideal so terminated this part
from textblob import TextBlob

# %%
def correct_spelling(text):
    return str(TextBlob(text).correct())

# %%
df["Corrected Meal"] = df["Meal"].apply(correct_spelling)

# %%
print(df[["Meal", "Corrected Meal"]])
# Out:
#                                                  Meal  \
# 0                         Fill The Freezer Care Packs
# 1                         Fill The Freezer With Soups
# 2                 Vegan Turmeric Coconut Curry + Tofu
# 3                    Vegan Mushroom & Quinoa Moussaka
# 4                    Courgette Spinach & Feta Lasagna
# 5                                          Beef Daube
# 6                                      Butter Chicken
# 7                                  Chicken & Leek Pie
# 8                                      Lamb Meatballs
# 9                                       Shepherds Pie
# 10                                    Smoked Fish Pie
# 11  Gluten-free Salted Caramel Chocolate Brownie D...
# 12      Sticky Date Pudding With Butterscotch Sauce 🍒
# 13                                      Fruit Crumble
#
#                                        Corrected Meal
# 0                           Will The Breeze Are Backs
# ...

# %% [markdown]
# Data cleansing:

# %%
# 1. Rename the first row, adding company's initial as FC+ 4 digit numbers, from 0001
df.rename(columns={'Unnamed: 0': 'Product ID'}, inplace=True)
df["Product ID"] = ["RD{:04d}".format(i + 1) for i in range(len(df))]

# %%
# 2.Idnetify if all the price are with more options, i.e. to check if all prices are with "from"
df['Price'].str.contains('from').all()
# Out:
# False

# %%
# Identify the row(s) without 'from'
df[~df['Price'].str.contains('from')]
# Out:
#    Product ID                                               Meal   Price  \
# 11     RD0012  Gluten-free Salted Caramel Chocolate Brownie D...  $32.00
#
#                                                   URL
# 11  /collections/instore-pickup-freezer-meals-bbq-...

# %%
# 3. Add a column next to 'Price', named 'Larger Size Available'.
df.insert(3, "Larger Size Available", False)

# %%
df["Larger Size Available"] = df["Price"].str.contains("from")

# %%
# 4. Conver the data type of "Price" to numeric type
df['Price'] = df['Price'].str.replace('from', '')

# %%
df["Price"] = df["Price"].str.replace("$", "").astype(float).round(2)

# %%
#5. Replace the URL with each product's full URL
df["URL"] = "https://www.ripedeli.co.nz/collections" + df["URL"]

# %%
df
# Out:
#    Product ID                                               Meal  Price  \
# 0      RD0001                        Fill The Freezer Care Packs  160.0
# 1      RD0002                        Fill The Freezer With Soups  116.0
# 2      RD0003                Vegan Turmeric Coconut Curry + Tofu   34.0
# 3      RD0004                   Vegan Mushroom & Quinoa Moussaka   34.0
# 4      RD0005                   Courgette Spinach & Feta Lasagna   34.0
# 5      RD0006                                         Beef Daube   36.0
# 6      RD0007                                     Butter Chicken   36.0
# 7      RD0008                                 Chicken & Leek Pie   36.0
# 8      RD0009                                     Lamb Meatballs   34.0
# 9      RD0010                                      Shepherds Pie   34.0
# 10     RD0011                                    Smoked Fish Pie   36.0
# 11     RD0012  Gluten-free Salted Caramel Chocolate Brownie D...   32.0
# ...

# %%
df.dtypes
# Out:
# Product ID                object
# Meal                      object
# Price                    float64
# Larger Size Available       bool
# URL                       object
# dtype: object

# %%
df.to_csv(r'/content/drive/MyDrive/DA612/RipeDeli_cleaned.csv')
